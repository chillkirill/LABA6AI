# %%
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import LabelEncoder

#  датасет adult через sklearn
adult = fetch_openml("adult", version=2, as_frame=True)
df = adult.frame  

print("Все столбцы датасета:")
print(df.columns.tolist(), end="\n\n")

# отбор нужных признаков с правильным именем целевого признака
df_selected = df[['education', 'marital-status', 'occupation', 'class']]

print("Исходные данные:")
print(df_selected.head(), end="\n\n")

le_education = LabelEncoder()
df_selected['education_encoded'] = le_education.fit_transform(df_selected['education'])

print("После Label Encoding признака 'education':")
print(df_selected[['education', 'education_encoded']], end="\n\n")

df_encoded = pd.get_dummies(df_selected, columns=['marital-status', 'occupation'], drop_first=False)

print("После One-Hot Encoding признаков 'marital-status' и 'occupation':")
print(df_encoded.head(), end="\n\n")

#  Проверка размерности таблицы до и после кодирования
print("Размерность до кодирования:", df_selected.shape)
print("Размерность после кодирования:", df_encoded.shape, end="\n\n")

#  Проверка дамми-ловушки
marital_cols = [col for col in df_encoded.columns if col.startswith('marital-status_')]
print("Корреляция между one-hot признаками 'marital-status':")
print(df_encoded[marital_cols].corr(), end="\n\n")

print("Если матрица корреляции содержит 1 между всеми столбцами, значит дамми-ловушка присутствует.")
print("Чтобы избежать дамми-ловушки, можно использовать drop_first=True в pd.get_dummies.")
# Out:
# Все столбцы датасета:
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'class']
#
# Исходные данные:
#       education      marital-status         occupation  class
# 0          11th       Never-married  Machine-op-inspct  <=50K
# 1       HS-grad  Married-civ-spouse    Farming-fishing  <=50K
# 2    Assoc-acdm  Married-civ-spouse    Protective-serv   >50K
# 3  Some-college  Married-civ-spouse  Machine-op-inspct   >50K
# 4  Some-college       Never-married                NaN  <=50K
#
# После Label Encoding признака 'education':
#           education  education_encoded
# 0              11th                  1
# 1           HS-grad                 11
# 2        Assoc-acdm                  7
# 3      Some-college                 15
# 4      Some-college                 15
# ...             ...                ...
# 48837    Assoc-acdm                  7
# 48838       HS-grad                 11
# 48839       HS-grad                 11
# 48840       HS-grad                 11
# 48841       HS-grad                 11
#
# [48842 rows x 2 columns]
#
# После One-Hot Encoding признаков 'marital-status' и 'occupation':
#       education  class  education_encoded  marital-status_Divorced  \
# 0          11th  <=50K                  1                    False
# 1       HS-grad  <=50K                 11                    False
# 2    Assoc-acdm   >50K                  7                    False
# 3  Some-college   >50K                 15                    False
# 4  Some-college  <=50K                 15                    False
#
#    marital-status_Married-AF-spouse  marital-status_Married-civ-spouse  \
# 0                             False                              False
# 1                             False                               True
# 2                             False                               True
# 3                             False                               True
# 4                             False                              False
#
#    marital-status_Married-spouse-absent  marital-status_Never-married  \
# 0                                 False                          True
# 1                                 False                         False
# 2                                 False                         False
# 3                                 False                         False
# 4                                 False                          True
#
#    marital-status_Separated  marital-status_Widowed  ...  \
# 0                     False                   False  ...
# 1                     False                   False  ...
# 2                     False                   False  ...
# 3                     False                   False  ...
# 4                     False                   False  ...
#
#    occupation_Farming-fishing  occupation_Handlers-cleaners  \
# 0                       False                         False
# 1                        True                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    occupation_Machine-op-inspct  occupation_Other-service  \
# 0                          True                     False
# 1                         False                     False
# 2                         False                     False
# 3                          True                     False
# 4                         False                     False
#
#    occupation_Priv-house-serv  occupation_Prof-specialty  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    occupation_Protective-serv  occupation_Sales  occupation_Tech-support  \
# 0                       False             False                    False
# 1                       False             False                    False
# 2                        True             False                    False
# 3                       False             False                    False
# 4                       False             False                    False
#
#    occupation_Transport-moving
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 24 columns]
#
# Размерность до кодирования: (48842, 5)
# Размерность после кодирования: (48842, 24)
#
# Корреляция между one-hot признаками 'marital-status':
#                                       marital-status_Divorced  \
# marital-status_Divorced                              1.000000
# marital-status_Married-AF-spouse                    -0.010915
# marital-status_Married-civ-spouse                   -0.364547
# marital-status_Married-spouse-absent                -0.045242
# marital-status_Never-married                        -0.278198
# marital-status_Separated                            -0.071287
# marital-status_Widowed                              -0.070998
#
#                                       marital-status_Married-AF-spouse  \
# marital-status_Divorced                                      -0.010915
# marital-status_Married-AF-spouse                              1.000000
# marital-status_Married-civ-spouse                            -0.025320
# marital-status_Married-spouse-absent                         -0.003142
# marital-status_Never-married                                 -0.019323
# marital-status_Separated                                     -0.004951
# marital-status_Widowed                                       -0.004931
#
#                                       marital-status_Married-civ-spouse  \
# marital-status_Divorced                                       -0.364547
# marital-status_Married-AF-spouse                              -0.025320
# marital-status_Married-civ-spouse                              1.000000
# marital-status_Married-spouse-absent                          -0.104953
# marital-status_Never-married                                  -0.645362
# marital-status_Separated                                      -0.165372
# marital-status_Widowed                                        -0.164701
#
#                                       marital-status_Married-spouse-absent  \
# marital-status_Divorced                                          -0.045242
# marital-status_Married-AF-spouse                                 -0.003142
# marital-status_Married-civ-spouse                                -0.104953
# marital-status_Married-spouse-absent                              1.000000
# marital-status_Never-married                                     -0.080093
# marital-status_Separated                                         -0.020524
# marital-status_Widowed                                           -0.020440
#
#                                       marital-status_Never-married  \
# marital-status_Divorced                                  -0.278198
# marital-status_Married-AF-spouse                         -0.019323
# marital-status_Married-civ-spouse                        -0.645362
# marital-status_Married-spouse-absent                     -0.080093
# marital-status_Never-married                              1.000000
# marital-status_Separated                                 -0.126201
# marital-status_Widowed                                   -0.125689
#
#                                       marital-status_Separated  \
# marital-status_Divorced                              -0.071287
# marital-status_Married-AF-spouse                     -0.004951
# marital-status_Married-civ-spouse                    -0.165372
# marital-status_Married-spouse-absent                 -0.020524
# marital-status_Never-married                         -0.126201
# marital-status_Separated                              1.000000
# marital-status_Widowed                               -0.032207
#
#                                       marital-status_Widowed
# marital-status_Divorced                            -0.070998
# marital-status_Married-AF-spouse                   -0.004931
# marital-status_Married-civ-spouse                  -0.164701
# marital-status_Married-spouse-absent               -0.020440
# marital-status_Never-married                       -0.125689
# marital-status_Separated                           -0.032207
# marital-status_Widowed                              1.000000
#
# Если матрица корреляции содержит 1 между всеми столбцами, значит дамми-ловушка присутствует.
# Чтобы избежать дамми-ловушки, можно использовать drop_first=True в pd.get_dummies.
# C:\Users\user\AppData\Local\Temp\ipykernel_8104\3202754986.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['education_encoded'] = le_education.fit_transform(df_selected['education'])
